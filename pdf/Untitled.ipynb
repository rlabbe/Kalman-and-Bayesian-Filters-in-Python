# %%
# %matplotlib notebook
from matplotlib.pyplot import *

# %%
from random import random

figure()
plot([random() for _ in range(20)]);
# Out:
# <img src="data:image/png;base64,...">

# %%
figure()
plot([random() for _ in range(20)]);
# Out:
# <img src="data:image/png;base64,...">
