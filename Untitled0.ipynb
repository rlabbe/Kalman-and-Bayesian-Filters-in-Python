# %%
#format the book
# %matplotlib inline
import book_format
book_format.load_style()
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
pylab.rcParams['figure.figsize'] = 12,6
pylab.rcParams['axes.facecolor'] = 'e5e5e5'
#pylab.rcParams['axes.facecolor'] = 'f8f8f8'
pylab.rcParams['grid.color'] = 'ffffff'
pylab.rcParams['grid.linestyle'] = 'solid'
pylab.rcParams['grid.linewidth'] = 1.5


plt.plot([1,2], label='1', color='#004080')
plt.plot([2,3], label='2', color='#8eba42')
plt.plot([3,4], label='3', color = '#e24a33')
plt.plot([4,5], label='4', color = '#348abd')
plt.plot([5,6], label='5', color = '#777760')
plt.plot([6,7], label='6', color = '#988ed5')
plt.plot([7,8], label='7', color = '#FDC15E')

#plt.plot([7,5,7,6,3,9,0,1,4,6], label='four')
#plt.plot([1,8,5,3,7,6,4,5], label='five')
#plt.plot([2,3,4,5,6,7,8,9], label='siz')
#plt.plot([9,8,7,6,5,4,3], label='7')
plt.legend(loc='best')

# %%
#
