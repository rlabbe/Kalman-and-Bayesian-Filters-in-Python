# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.plot([1,3,6, 2]);

# %%
import time
# %matplotlib notebook
plt.plot([1,3,6,1]);
time.sleep(0.05)
plt.gcf().canvas.draw()
# %matplotlib inline
# Out:
# <img src="data:image/png;base64,...">
